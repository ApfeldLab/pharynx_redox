# %%
% matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df_410 = pd.read_csv('/Users/sean/Desktop/profiles_410.csv', index_col=0)
df_470 = pd.read_csv('/Users/sean/Desktop/profiles_470.csv', index_col=0)
labels = pd.read_csv('raw_data/labels.csv')

# %%
labels.shape
# Out:
# (1196, 2)

# %%
df_410.plot(legend=False)

# %%
df_470.plot(legend=False)

# %%
df_410_np = np.asarray(df_410)

# %%
df_410_np.shape
# Out:
# (114, 1196)

# %%
profiles_410 = [df_410_np[:,i] for i in range(df_410_np.shape[1])]

# %%
thresh_410 = [prof[prof>2000] for prof in profiles_410]

# %%
from scipy.interpolate import interp1d
from scipy.misc import imresize

data = thresh_410[0]
xloc = np.arange(len(data))
newsize = 100

new_xloc = np.linspace(0, len(data), newsize)
new_data = np.interp(new_xloc, xloc, data)
plt.plot(new_xloc, new_data)

# %%
data = thresh_410[30]
xloc = np.arange(len(data))
newsize = 100

new_xloc = np.linspace(0, len(data), newsize)
new_data = np.interp(new_xloc, xloc, data)
plt.plot(new_xloc, new_data)
