# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pharedox import pio, profile_processing as pp
import matplotlib.pyplot as plt
import numpy as np

# %%
import yaml

# %%
with open('pharedox/default-settings.yaml', 'r') as f:
    default_settings = yaml.load(f, Loader=yaml.FullLoader)

# %%
std = pio.load_profile_data('/Users/sean/code/error_paper/data/preprocessed/std_untrimmed_profiles.nc').sel(animal=slice(0, 10))
raw = pio.load_profile_data('/Users/sean/code/error_paper/data/preprocessed/raw_untrimmed_profiles.nc').sel(animal=slice(0, 10))

# %%
raw.sel(wavelength='410', pair=0, timepoint=0).plot.line(x='position', add_legend=False);

# %%
template = np.loadtxt('/Users/sean/code/pharynx_redox/pharedox/standardization_template.txt')

# %%
test_std, test_warp = pp.standardize_profiles(raw, redox_params=default_settings['redox'], template=template, **default_settings['registration'])
test_std.sel(wavelength='410', pair=0, timepoint=0).plot.line(x='position', add_legend=False);

# %%
std.sel(wavelength='410', pair=0, timepoint=0).plot.line(x='position', add_legend=False);
