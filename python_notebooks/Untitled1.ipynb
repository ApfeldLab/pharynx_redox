# %%
# %matplotlib inline

from skimage.external.tifffile import imread
import matplotlib.pyplot as plt
import matplotlib

import numpy as np

# %%
ims = np.asarray(imread("/Users/sean/code/wormAnalysis/matlab/sean/analysis/01-28-19 weighted midline/data/WT high mvmt 11-19-18.tif"), dtype='int16')

# %%
plt.imshow(ims[239,:,:])

# %%
plt.imshow(ims[240,:,:])

# %%
plt.imshow(ims[239,:,:] - ims[240,:,:])

# %%
_=plt.hist(ims[239,:,:] - ims[240,:,:], range=[-60,60])

# %%
diff = ims[239,:,:] - ims[240,:,:]

mask_239 = ims[239,:,:]
mask_239[mask_239 < 2000] = 0
mask_239[mask_239 >= 2000] = 1

mask_240 = ims[240,:,:]
mask_240[mask_240 < 2000] = 0
mask_240[mask_240 >= 2000] = 1
