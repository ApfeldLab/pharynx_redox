# %%
from pharynx_analysis import experiment
from pathlib import Path
import logging
import pandas as pd

logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.INFO, datefmt='%I:%M:%S')

# %%
meta_dir = Path("/Users/sean/code/wormAnalysis/data/paired_ratio/")
imaging_scheme = "TL/470/410/470/410"

for exp_dir in meta_dir.iterdir():
    if exp_dir.is_dir():
        ex = experiment.PairExperiment(experiment_dir=exp_dir, imaging_scheme=imaging_scheme)
        ex.persist_to_disk()
        ex.generate_per_animal_reports()
# Out:
# ...
# 100%|██████████| 121/121 [00:03<00:00, 32.39it/s]
# /Users/sean/.local/share/virtualenvs/worm/lib/python3.7/site-packages/xarray/core/computation.py:564: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# /Users/sean/.local/share/virtualenvs/worm/lib/python3.7/site-packages/xarray/core/nanops.py:160: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
#   0%|          | 0/121 [00:00<?, ?it/s]../pharynx_analysis/plots.py:224: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(constrained_layout=True, figsize=(15, 15))
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ...

# %%
pd.concat([pd.read_csv(x) for x in (meta_dir.glob('**/*summary*csv'))]).to_csv('/Users/sean/Desktop/all_region_means.csv', index=False)
