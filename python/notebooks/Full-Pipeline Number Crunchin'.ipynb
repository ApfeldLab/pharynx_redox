# %%
from pharynx_analysis import (
    pharynx_io as pio, 
    image_processing as ip, 
    experiment, 
    plots, 
    profile_processing,
    data_analysis as da
)

import xarray as xr
from pathlib import Path
from tqdm import tqdm_notebook
from scipy import signal
import seaborn as sns
from importlib import reload
import numpy as np
import logging
import pandas as pd
import matplotlib.pyplot as plt

reload(logging)
reload(experiment)
reload(pio)
reload(ip)
reload(plots)
reload(profile_processing)
reload(da)

# pd.set_option('display.height', 500)
pd.set_option('display.max_rows', 100)

logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.DEBUG, datefmt='%I:%M:%S')

# %%
meta_dir = Path("/Users/sean/code/wormAnalysis/data/paired_ratio")
imaging_scheme = "TL/470/410/470/410"

exps = list(filter(lambda x: x.is_dir(), meta_dir.iterdir()))
exp_objs = []
for exp_dir in tqdm_notebook(exps):
    ex_reg = experiment.PairExperiment(
        experiment_dir = exp_dir,
        imaging_scheme = imaging_scheme,
        should_register = True,
        save_summary_plots=False,
        strategy='skfda_reg',
        warp_lam=10**-.5
    )
    ex_reg.full_pipeline()
    
    ex_unreg = experiment.PairExperiment(
        experiment_dir = exp_dir,
        imaging_scheme = imaging_scheme,
        should_register = False,
        save_summary_plots=False,
        strategy='unreg',
    )
    ex_unreg.full_pipeline()
    
    plots.save_reg_diagnostics(ex_unreg, ex_reg, f'/Users/sean/Desktop/diags/{ex_reg.experiment_id}.pdf')
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# 03:16:30 INFO:Starting full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_23-HD233_4mm_lev
# 03:16:30 INFO:Loading Images
# 03:16:31 INFO:Segmenting pharynxes
# 03:16:31 INFO:Centering and rotating pharynxes
# 100%|██████████| 28/28 [00:01<00:00, 15.90it/s]
# 03:16:33 INFO:Calculating midlines
# 100%|██████████| 28/28 [00:00<00:00, 110.31it/s]
# 03:16:33 INFO:Measuring under midlines
# 100%|██████████| 28/28 [00:00<00:00, 116.10it/s]
# 03:16:34 INFO:Registering profiles
# 03:16:55 INFO:Trimming intensity data
# 03:16:55 INFO:Calculating redox measurements
# 03:16:55 INFO:Saving 2017_08_23-HD233_4mm_lev inside /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_23-HD233_4mm_lev
# 03:16:55 INFO:Saving region means to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_23-HD233_4mm_lev/analyses/2019-08-29_skfda_reg/2017_08_23-HD233_4mm_lev-summary_table.csv
# 03:16:55 INFO:Saving profile data to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_23-HD233_4mm_lev/analyses/2019-08-29_skfda_reg/2017_08_23-HD233_4mm_lev-profile_data.nc
# 03:16:55 INFO:Finished full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_23-HD233_4mm_lev
# 03:16:56 INFO:Starting full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_23-HD233_4mm_lev
# 03:16:56 INFO:Loading Images
# 03:16:56 INFO:Segmenting pharynxes
# 03:16:56 INFO:Centering and rotating pharynxes
# 100%|██████████| 28/28 [00:01<00:00, 16.52it/s]
# 03:16:58 INFO:Calculating midlines
# 100%|██████████| 28/28 [00:00<00:00, 126.10it/s]
# 03:16:58 INFO:Measuring under midlines
# 100%|██████████| 28/28 [00:00<00:00, 129.38it/s]
# 03:16:59 INFO:Trimming intensity data
# 03:16:59 INFO:Calculating redox measurements
# 03:16:59 INFO:Saving 2017_08_23-HD233_4mm_lev inside /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_23-HD233_4mm_lev
# 03:16:59 INFO:Saving region means to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_23-HD233_4mm_lev/analyses/2019-08-29_unreg/2017_08_23-HD233_4mm_lev-summary_table.csv
# 03:16:59 INFO:Saving profile data to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_23-HD233_4mm_lev/analyses/2019-08-29_unreg/2017_08_23-HD233_4mm_lev-profile_data.nc
# 03:16:59 INFO:Finished full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_23-HD233_4mm_lev
# 100%|██████████| 28/28 [00:44<00:00,  1.83s/it]
# 03:17:44 INFO:Starting full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_22-HD233_SAY47
# 03:17:44 INFO:Loading Images
# 03:17:45 INFO:Segmenting pharynxes
# 03:17:46 INFO:Centering and rotating pharynxes
# 100%|██████████| 123/123 [00:08<00:00, 15.23it/s]
# 03:17:55 INFO:Calculating midlines
# 100%|██████████| 123/123 [00:01<00:00, 97.02it/s]
# 03:17:57 INFO:Measuring under midlines
# 100%|██████████| 123/123 [00:01<00:00, 105.81it/s]
# 03:17:58 INFO:Registering profiles
# 03:18:34 INFO:Trimming intensity data
# 03:18:35 INFO:Calculating redox measurements
# 03:18:35 INFO:Saving 2017_02_22-HD233_SAY47 inside /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_22-HD233_SAY47
# 03:18:35 INFO:Saving region means to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_22-HD233_SAY47/analyses/2019-08-29_skfda_reg/2017_02_22-HD233_SAY47-summary_table.csv
# 03:18:35 INFO:Saving profile data to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_22-HD233_SAY47/analyses/2019-08-29_skfda_reg/2017_02_22-HD233_SAY47-profile_data.nc
# 03:18:35 INFO:Finished full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_22-HD233_SAY47
# 03:18:35 INFO:Starting full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_22-HD233_SAY47
# 03:18:35 INFO:Loading Images
# 03:18:36 INFO:Segmenting pharynxes
# 03:18:37 INFO:Centering and rotating pharynxes
# 100%|██████████| 123/123 [00:07<00:00, 15.88it/s]
# 03:18:46 INFO:Calculating midlines
# 100%|██████████| 123/123 [00:01<00:00, 101.51it/s]
# 03:18:47 INFO:Measuring under midlines
# 100%|██████████| 123/123 [00:01<00:00, 116.12it/s]
# 03:18:48 INFO:Trimming intensity data
# 03:18:49 INFO:Calculating redox measurements
# 03:18:49 INFO:Saving 2017_02_22-HD233_SAY47 inside /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_22-HD233_SAY47
# 03:18:49 INFO:Saving region means to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_22-HD233_SAY47/analyses/2019-08-29_unreg/2017_02_22-HD233_SAY47-summary_table.csv
# 03:18:50 INFO:Saving profile data to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_22-HD233_SAY47/analyses/2019-08-29_unreg/2017_02_22-HD233_SAY47-profile_data.nc
# 03:18:50 INFO:Finished full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_22-HD233_SAY47
# 100%|██████████| 123/123 [02:45<00:00,  1.15s/it]
# 03:21:38 INFO:Starting full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_25-HD233_SAY93
# 03:21:38 INFO:Loading Images
# 03:21:39 INFO:Segmenting pharynxes
# 03:21:39 INFO:Centering and rotating pharynxes
# 100%|██████████| 35/35 [00:02<00:00, 15.52it/s]
# 03:21:42 INFO:Calculating midlines
# 100%|██████████| 35/35 [00:00<00:00, 110.90it/s]
# 03:21:42 INFO:Measuring under midlines
# 100%|██████████| 35/35 [00:00<00:00, 119.57it/s]
# 03:21:42 INFO:Registering profiles
# 03:22:02 INFO:Trimming intensity data
# 03:22:02 INFO:Calculating redox measurements
# 03:22:03 INFO:Saving 2017_08_25-HD233_SAY93 inside /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_25-HD233_SAY93
# 03:22:03 INFO:Saving region means to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_25-HD233_SAY93/analyses/2019-08-29_skfda_reg/2017_08_25-HD233_SAY93-summary_table.csv
# 03:22:03 INFO:Saving profile data to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_25-HD233_SAY93/analyses/2019-08-29_skfda_reg/2017_08_25-HD233_SAY93-profile_data.nc
# 03:22:03 INFO:Finished full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_25-HD233_SAY93
# 03:22:03 INFO:Starting full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_25-HD233_SAY93
# 03:22:03 INFO:Loading Images
# 03:22:03 INFO:Segmenting pharynxes
# 03:22:03 INFO:Centering and rotating pharynxes
# 100%|██████████| 35/35 [00:02<00:00, 15.24it/s]
# 03:22:06 INFO:Calculating midlines
# 100%|██████████| 35/35 [00:00<00:00, 103.34it/s]
# 03:22:06 INFO:Measuring under midlines
# 100%|██████████| 35/35 [00:00<00:00, 106.53it/s]
# 03:22:07 INFO:Trimming intensity data
# 03:22:07 INFO:Calculating redox measurements
# 03:22:07 INFO:Saving 2017_08_25-HD233_SAY93 inside /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_25-HD233_SAY93
# 03:22:07 INFO:Saving region means to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_25-HD233_SAY93/analyses/2019-08-29_unreg/2017_08_25-HD233_SAY93-summary_table.csv
# 03:22:08 INFO:Saving profile data to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_25-HD233_SAY93/analyses/2019-08-29_unreg/2017_08_25-HD233_SAY93-profile_data.nc
# 03:22:08 INFO:Finished full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_25-HD233_SAY93
# 100%|██████████| 35/35 [00:43<00:00,  1.14s/it]
# 03:22:52 INFO:Starting full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_23-HD233_HD236
# 03:22:52 INFO:Loading Images
# 03:22:53 INFO:Segmenting pharynxes
# 03:22:54 INFO:Centering and rotating pharynxes
# 100%|██████████| 109/109 [00:06<00:00, 15.78it/s]
# 03:23:02 INFO:Calculating midlines
# 100%|██████████| 109/109 [00:00<00:00, 115.19it/s]
# 03:23:03 INFO:Measuring under midlines
# 100%|██████████| 109/109 [00:00<00:00, 117.32it/s]
# 03:23:04 INFO:Registering profiles
# 03:23:33 INFO:Trimming intensity data
# 03:23:34 INFO:Calculating redox measurements
# 03:23:34 INFO:Saving 2017_02_23-HD233_HD236 inside /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_23-HD233_HD236
# 03:23:34 INFO:Saving region means to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_23-HD233_HD236/analyses/2019-08-29_skfda_reg/2017_02_23-HD233_HD236-summary_table.csv
# 03:23:35 INFO:Saving profile data to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_23-HD233_HD236/analyses/2019-08-29_skfda_reg/2017_02_23-HD233_HD236-profile_data.nc
# 03:23:35 INFO:Finished full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_23-HD233_HD236
# 03:23:35 INFO:Starting full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_23-HD233_HD236
# 03:23:35 INFO:Loading Images
# 03:23:35 INFO:Segmenting pharynxes
# 03:23:36 INFO:Centering and rotating pharynxes
# 100%|██████████| 109/109 [00:06<00:00, 16.28it/s]
# 03:23:44 INFO:Calculating midlines
# 100%|██████████| 109/109 [00:00<00:00, 119.33it/s]
# 03:23:45 INFO:Measuring under midlines
# 100%|██████████| 109/109 [00:00<00:00, 125.95it/s]
# 03:23:45 INFO:Trimming intensity data
# 03:23:46 INFO:Calculating redox measurements
# 03:23:46 INFO:Saving 2017_02_23-HD233_HD236 inside /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_23-HD233_HD236
# 03:23:46 INFO:Saving region means to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_23-HD233_HD236/analyses/2019-08-29_unreg/2017_02_23-HD233_HD236-summary_table.csv
# 03:23:47 INFO:Saving profile data to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_23-HD233_HD236/analyses/2019-08-29_unreg/2017_02_23-HD233_HD236-profile_data.nc
# 03:23:47 INFO:Finished full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_23-HD233_HD236
# 100%|██████████| 109/109 [02:13<00:00,  1.15s/it]
# 03:26:04 INFO:Starting full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_03_01_HD233_HD236
# 03:26:04 INFO:Loading Images
# 03:26:05 INFO:Segmenting pharynxes
# 03:26:07 INFO:Centering and rotating pharynxes
# 100%|██████████| 120/120 [00:07<00:00, 16.39it/s]
# 03:26:15 INFO:Calculating midlines
# 100%|██████████| 120/120 [00:01<00:00, 113.98it/s]
# 03:26:16 INFO:Measuring under midlines
# 100%|██████████| 120/120 [00:01<00:00, 119.07it/s]
# 03:26:17 INFO:Registering profiles
# 03:26:49 INFO:Trimming intensity data
# 03:26:50 INFO:Calculating redox measurements
# 03:26:50 INFO:Saving 2017_03_01_HD233_HD236 inside /Users/sean/code/wormAnalysis/data/paired_ratio/2017_03_01_HD233_HD236
# 03:26:50 INFO:Saving region means to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_03_01_HD233_HD236/analyses/2019-08-29_skfda_reg/2017_03_01_HD233_HD236-summary_table.csv
# 03:26:51 INFO:Saving profile data to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_03_01_HD233_HD236/analyses/2019-08-29_skfda_reg/2017_03_01_HD233_HD236-profile_data.nc
# 03:26:51 INFO:Finished full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_03_01_HD233_HD236
# 03:26:51 INFO:Starting full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_03_01_HD233_HD236
# 03:26:51 INFO:Loading Images
# 03:26:52 INFO:Segmenting pharynxes
# 03:26:53 INFO:Centering and rotating pharynxes
# 100%|██████████| 120/120 [00:08<00:00, 14.41it/s]
# 03:27:02 INFO:Calculating midlines
# 100%|██████████| 120/120 [00:01<00:00, 98.76it/s]
# 03:27:03 INFO:Measuring under midlines
# 100%|██████████| 120/120 [00:01<00:00, 117.44it/s]
# 03:27:04 INFO:Trimming intensity data
# 03:27:05 INFO:Calculating redox measurements
# 03:27:06 INFO:Saving 2017_03_01_HD233_HD236 inside /Users/sean/code/wormAnalysis/data/paired_ratio/2017_03_01_HD233_HD236
# 03:27:06 INFO:Saving region means to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_03_01_HD233_HD236/analyses/2019-08-29_unreg/2017_03_01_HD233_HD236-summary_table.csv
# 03:27:06 INFO:Saving profile data to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_03_01_HD233_HD236/analyses/2019-08-29_unreg/2017_03_01_HD233_HD236-profile_data.nc
# 03:27:06 INFO:Finished full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_03_01_HD233_HD236
# 100%|██████████| 120/120 [02:48<00:00,  1.21s/it]
# 03:29:59 INFO:Starting full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2019_04_03_ASI_ablation
# 03:29:59 INFO:Loading Images
# 03:29:59 INFO:Segmenting pharynxes
# 03:30:01 INFO:Centering and rotating pharynxes
# 100%|██████████| 123/123 [00:08<00:00, 15.37it/s]
# 03:30:10 INFO:Calculating midlines
# 100%|██████████| 123/123 [00:01<00:00, 101.07it/s]
# 03:30:11 INFO:Measuring under midlines
# 100%|██████████| 123/123 [00:01<00:00, 111.08it/s]
# 03:30:12 INFO:Registering profiles
# 03:30:45 INFO:Trimming intensity data
# 03:30:46 INFO:Calculating redox measurements
# /Users/sean/.local/share/virtualenvs/worm/lib/python3.7/site-packages/xarray/core/computation.py:564: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# 03:30:46 INFO:Saving 2019_04_03_ASI_ablation inside /Users/sean/code/wormAnalysis/data/paired_ratio/2019_04_03_ASI_ablation
# 03:30:46 INFO:Saving region means to /Users/sean/code/wormAnalysis/data/paired_ratio/2019_04_03_ASI_ablation/analyses/2019-08-29_skfda_reg/2019_04_03_ASI_ablation-summary_table.csv
# 03:30:46 INFO:Saving profile data to /Users/sean/code/wormAnalysis/data/paired_ratio/2019_04_03_ASI_ablation/analyses/2019-08-29_skfda_reg/2019_04_03_ASI_ablation-profile_data.nc
# 03:30:46 INFO:Finished full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2019_04_03_ASI_ablation
# 03:30:47 INFO:Starting full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2019_04_03_ASI_ablation
# 03:30:47 INFO:Loading Images
# 03:30:47 INFO:Segmenting pharynxes
# 03:30:49 INFO:Centering and rotating pharynxes
# 100%|██████████| 123/123 [00:08<00:00, 14.29it/s]
# 03:30:58 INFO:Calculating midlines
# 100%|██████████| 123/123 [00:01<00:00, 89.58it/s]
# 03:31:00 INFO:Measuring under midlines
# 100%|██████████| 123/123 [00:01<00:00, 109.47it/s]
# 03:31:01 INFO:Trimming intensity data
# 03:31:02 INFO:Calculating redox measurements
# /Users/sean/.local/share/virtualenvs/worm/lib/python3.7/site-packages/xarray/core/computation.py:564: RuntimeWarning: invalid value encountered in log
#   result_data = func(*input_data)
# 03:31:02 INFO:Saving 2019_04_03_ASI_ablation inside /Users/sean/code/wormAnalysis/data/paired_ratio/2019_04_03_ASI_ablation
# 03:31:02 INFO:Saving region means to /Users/sean/code/wormAnalysis/data/paired_ratio/2019_04_03_ASI_ablation/analyses/2019-08-29_unreg/2019_04_03_ASI_ablation-summary_table.csv
# 03:31:03 INFO:Saving profile data to /Users/sean/code/wormAnalysis/data/paired_ratio/2019_04_03_ASI_ablation/analyses/2019-08-29_unreg/2019_04_03_ASI_ablation-profile_data.nc
# 03:31:03 INFO:Finished full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2019_04_03_ASI_ablation
# 100%|██████████| 123/123 [02:58<00:00,  1.49s/it]
# 03:34:05 INFO:Starting full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_15-HD233_4mM_lev
# 03:34:05 INFO:Loading Images
# 03:34:06 INFO:Segmenting pharynxes
# 03:34:07 INFO:Centering and rotating pharynxes
# 100%|██████████| 80/80 [00:04<00:00, 16.25it/s]
# 03:34:12 INFO:Calculating midlines
# 100%|██████████| 80/80 [00:00<00:00, 113.25it/s]
# 03:34:13 INFO:Measuring under midlines
# 100%|██████████| 80/80 [00:00<00:00, 121.62it/s]
# 03:34:14 INFO:Registering profiles
# 03:34:41 INFO:Trimming intensity data
# 03:34:41 INFO:Calculating redox measurements
# 03:34:42 INFO:Saving 2017_08_15-HD233_4mM_lev inside /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_15-HD233_4mM_lev
# 03:34:42 INFO:Saving region means to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_15-HD233_4mM_lev/analyses/2019-08-29_skfda_reg/2017_08_15-HD233_4mM_lev-summary_table.csv
# 03:34:42 INFO:Saving profile data to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_15-HD233_4mM_lev/analyses/2019-08-29_skfda_reg/2017_08_15-HD233_4mM_lev-profile_data.nc
# 03:34:42 INFO:Finished full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_15-HD233_4mM_lev
# 03:34:42 INFO:Starting full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_15-HD233_4mM_lev
# 03:34:42 INFO:Loading Images
# 03:34:42 INFO:Segmenting pharynxes
# 03:34:43 INFO:Centering and rotating pharynxes
# 100%|██████████| 80/80 [00:05<00:00, 16.25it/s]
# 03:34:50 INFO:Calculating midlines
# 100%|██████████| 80/80 [00:00<00:00, 112.13it/s]
# 03:34:50 INFO:Measuring under midlines
# 100%|██████████| 80/80 [00:00<00:00, 118.20it/s]
# 03:34:51 INFO:Trimming intensity data
# 03:34:52 INFO:Calculating redox measurements
# 03:34:52 INFO:Saving 2017_08_15-HD233_4mM_lev inside /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_15-HD233_4mM_lev
# 03:34:52 INFO:Saving region means to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_15-HD233_4mM_lev/analyses/2019-08-29_unreg/2017_08_15-HD233_4mM_lev-summary_table.csv
# 03:34:52 INFO:Saving profile data to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_15-HD233_4mM_lev/analyses/2019-08-29_unreg/2017_08_15-HD233_4mM_lev-profile_data.nc
# 03:34:52 INFO:Finished full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_15-HD233_4mM_lev
# 100%|██████████| 80/80 [01:47<00:00,  1.25s/it]
# 03:36:43 INFO:Starting full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_24-HD233_SAY93
# 03:36:43 INFO:Loading Images
# 03:37:40 INFO:Segmenting pharynxes
# 03:37:41 INFO:Centering and rotating pharynxes
# 100%|██████████| 90/90 [00:05<00:00, 16.42it/s]
# 03:37:47 INFO:Calculating midlines
# 100%|██████████| 90/90 [00:00<00:00, 117.78it/s]
# 03:37:48 INFO:Measuring under midlines
# 100%|██████████| 90/90 [00:00<00:00, 110.41it/s]
# 03:37:49 INFO:Registering profiles
# 03:38:18 INFO:Trimming intensity data
# 03:38:18 INFO:Calculating redox measurements
# 03:38:19 INFO:Saving 2017_08_24-HD233_SAY93 inside /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_24-HD233_SAY93
# 03:38:19 INFO:Saving region means to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_24-HD233_SAY93/analyses/2019-08-29_skfda_reg/2017_08_24-HD233_SAY93-summary_table.csv
# 03:38:19 INFO:Saving profile data to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_24-HD233_SAY93/analyses/2019-08-29_skfda_reg/2017_08_24-HD233_SAY93-profile_data.nc
# 03:38:19 INFO:Finished full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_24-HD233_SAY93
# 03:38:19 INFO:Starting full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_24-HD233_SAY93
# 03:38:19 INFO:Loading Images
# 03:38:20 INFO:Segmenting pharynxes
# 03:38:21 INFO:Centering and rotating pharynxes
# 100%|██████████| 90/90 [00:05<00:00, 16.54it/s]
# 03:38:27 INFO:Calculating midlines
# 100%|██████████| 90/90 [00:00<00:00, 124.16it/s]
# 03:38:28 INFO:Measuring under midlines
# 100%|██████████| 90/90 [00:00<00:00, 129.92it/s]
# 03:38:28 INFO:Trimming intensity data
# 03:38:29 INFO:Calculating redox measurements
# 03:38:29 INFO:Saving 2017_08_24-HD233_SAY93 inside /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_24-HD233_SAY93
# 03:38:29 INFO:Saving region means to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_24-HD233_SAY93/analyses/2019-08-29_unreg/2017_08_24-HD233_SAY93-summary_table.csv
# 03:38:29 INFO:Saving profile data to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_24-HD233_SAY93/analyses/2019-08-29_unreg/2017_08_24-HD233_SAY93-profile_data.nc
# 03:38:29 INFO:Finished full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_24-HD233_SAY93
# 100%|██████████| 90/90 [01:48<00:00,  1.14s/it]
# 03:40:21 INFO:Starting full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_27-HD233_HD236
# 03:40:21 INFO:Loading Images
# 03:40:22 INFO:Segmenting pharynxes
# 03:40:23 INFO:Centering and rotating pharynxes
# 100%|██████████| 120/120 [00:07<00:00, 16.39it/s]
# 03:40:31 INFO:Calculating midlines
# 100%|██████████| 120/120 [00:01<00:00, 112.57it/s]
# 03:40:33 INFO:Measuring under midlines
# 100%|██████████| 120/120 [00:01<00:00, 103.67it/s]
# 03:40:34 INFO:Registering profiles
# 03:41:10 INFO:Trimming intensity data
# 03:41:10 INFO:Calculating redox measurements
# 03:41:11 INFO:Saving 2017_02_27-HD233_HD236 inside /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_27-HD233_HD236
# 03:41:11 INFO:Saving region means to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_27-HD233_HD236/analyses/2019-08-29_skfda_reg/2017_02_27-HD233_HD236-summary_table.csv
# 03:41:11 INFO:Saving profile data to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_27-HD233_HD236/analyses/2019-08-29_skfda_reg/2017_02_27-HD233_HD236-profile_data.nc
# 03:41:11 INFO:Finished full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_27-HD233_HD236
# 03:41:11 INFO:Starting full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_27-HD233_HD236
# 03:41:11 INFO:Loading Images
# 03:41:12 INFO:Segmenting pharynxes
# 03:41:13 INFO:Centering and rotating pharynxes
# 100%|██████████| 120/120 [00:11<00:00,  6.70it/s]
# 03:41:25 INFO:Calculating midlines
# 100%|██████████| 120/120 [00:02<00:00, 51.93it/s]
# 03:41:28 INFO:Measuring under midlines
# 100%|██████████| 120/120 [00:01<00:00, 96.80it/s]
# 03:41:29 INFO:Trimming intensity data
# 03:41:30 INFO:Calculating redox measurements
# 03:41:30 INFO:Saving 2017_02_27-HD233_HD236 inside /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_27-HD233_HD236
# 03:41:30 INFO:Saving region means to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_27-HD233_HD236/analyses/2019-08-29_unreg/2017_02_27-HD233_HD236-summary_table.csv
# 03:41:31 INFO:Saving profile data to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_27-HD233_HD236/analyses/2019-08-29_unreg/2017_02_27-HD233_HD236-profile_data.nc
# 03:41:31 INFO:Finished full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_02_27-HD233_HD236
# 100%|██████████| 120/120 [05:17<00:00,  1.62s/it]
# 03:46:53 INFO:Starting full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_25-HD233_4mm_lev
# 03:46:53 INFO:Loading Images
# 03:46:53 INFO:Segmenting pharynxes
# 03:46:54 INFO:Centering and rotating pharynxes
# 100%|██████████| 35/35 [00:02<00:00, 14.20it/s]
# 03:46:57 INFO:Calculating midlines
# 100%|██████████| 35/35 [00:00<00:00, 109.16it/s]
# 03:46:57 INFO:Measuring under midlines
# 100%|██████████| 35/35 [00:00<00:00, 116.98it/s]
# 03:46:57 INFO:Registering profiles
# 03:47:20 INFO:Trimming intensity data
# 03:47:20 INFO:Calculating redox measurements
# 03:47:20 INFO:Saving 2017_08_25-HD233_4mm_lev inside /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_25-HD233_4mm_lev
# 03:47:20 INFO:Saving region means to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_25-HD233_4mm_lev/analyses/2019-08-29_skfda_reg/2017_08_25-HD233_4mm_lev-summary_table.csv
# 03:47:21 INFO:Saving profile data to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_25-HD233_4mm_lev/analyses/2019-08-29_skfda_reg/2017_08_25-HD233_4mm_lev-profile_data.nc
# 03:47:21 INFO:Finished full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_25-HD233_4mm_lev
# 03:47:21 INFO:Starting full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_25-HD233_4mm_lev
# 03:47:21 INFO:Loading Images
# 03:47:21 INFO:Segmenting pharynxes
# 03:47:21 INFO:Centering and rotating pharynxes
# 100%|██████████| 35/35 [00:02<00:00, 16.49it/s]
# 03:47:24 INFO:Calculating midlines
# 100%|██████████| 35/35 [00:00<00:00, 119.30it/s]
# 03:47:24 INFO:Measuring under midlines
# 100%|██████████| 35/35 [00:00<00:00, 126.18it/s]
# 03:47:24 INFO:Trimming intensity data
# 03:47:25 INFO:Calculating redox measurements
# 03:47:25 INFO:Saving 2017_08_25-HD233_4mm_lev inside /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_25-HD233_4mm_lev
# 03:47:25 INFO:Saving region means to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_25-HD233_4mm_lev/analyses/2019-08-29_unreg/2017_08_25-HD233_4mm_lev-summary_table.csv
# 03:47:25 INFO:Saving profile data to /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_25-HD233_4mm_lev/analyses/2019-08-29_unreg/2017_08_25-HD233_4mm_lev-profile_data.nc
# 03:47:25 INFO:Finished full pipeline run for /Users/sean/code/wormAnalysis/data/paired_ratio/2017_08_25-HD233_4mm_lev
# 100%|██████████| 35/35 [00:40<00:00,  1.14s/it]
